# %%
import bcrypt

admins = [
    ("Andreas Dezen Silva","andreas.germinare@gmail.com","11978562442","2010-08-16","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_1_nsvs4o.jpg"),
    ("Beatriz Teixeira Marioti","b.tmarioti3.0@gmail.com","11913139297","2008-09-09","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.02_gmd38y.jpg"),
    ("Caio de Oliveira Garcia","caiodegarcia.oficial@gmail.com","11984858093","2008-05-20","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761661655/WhatsApp_Image_2025-10-28_at_10.03.59_g0coyl.jpg"),
    ("Enzo D´angio Mota","enzo.mota@germinare.org.br","11992866128","2010-03-te12","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_g97uhz.jpg"),
    ("Gabriel Ferreira Texeira","gabriel.ferreira@germinare.org.br","11972721701","2009-01-17","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575509/WhatsApp_Image_2025-10-27_at_11.31.31_nsvwb1.jpg"),
    ("Giovanna Almeida dos Santos","gihalmeida127@gmail.com","11942026405","2010-01-17","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575151/WhatsApp_Image_2025-10-27_at_11.21.58_lhk3eg.jpg"),
    ("Giovanna Medeiros Veloso","giovanna.veloso@germinare.org.br","11997831648","2009-07-31","Desenvolvedora","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575133/WhatsApp_Image_2025-10-27_at_11.21.57_atpip0.jpg"),
    ("Giulia Galeote Santana Oliveira","giulia.gso.2008@gmail.com","11953062483","2008-08-19","Desenvolvedora","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.03_1_pz2e42.jpg"),
    ("Giulia Monteiro Manara","giulia.manara@germinare.org.br","11969803064","2009-06-09","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.00_efzdhe.jpg"),
    ("Lívia Izidório","liviaizidorio.li@gmail.com","11987307953","2008-12-22","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.03_u0h0ra.jpg"),
    ("Luis Henrique Medeiros","luis.medeiros@germinare.org.br","11939603223","2009-04-05","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.21.57_1_zmppzr.jpg"),
    ("Luke Francischini Pereira dos Santos","pereiraluke12@gmail.com","11960648215","2008-11-25","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575152/WhatsApp_Image_2025-10-27_at_11.21.58_1_aaxtkx.jpg"),
    ("Mariana Marrão Ferreira Felis","mariana.felis@germinare.org.br","11941286166","2010-01-15","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.21.59_zxvoix.jpg"),
    ("Marcos Guilherme Araújo","marcosedaviaraujo@gmail.com","11950056954","2009-01-02","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575152/WhatsApp_Image_2025-10-27_at_11.21.58_1_aaxtkx.jpg"),
    ("Matheus Lima Botana Gama","matheus.gama@germinare.org.br","11983147995","2010-02-14","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575158/WhatsApp_Image_2025-10-27_at_11.21.57_2_jeb7au.jpg")
]

senha_plain = "1234567810"
tuplas_sql = []

for nome, email, telefone, nascimento, cargo, foto in admins:
    hash_bytes = bcrypt.hashpw(senha_plain.encode('utf-8'), bcrypt.gensalt(12))
    senha_hash = hash_bytes.decode('utf-8')
    senha_hash_java = senha_hash.replace("$2b$", "$2a$").replace("$2y$", "$2a$")

    nome_esc = nome.replace("'", "''")
    email_esc = email.replace("'", "''")
    foto_esc = foto.replace("'", "''")
    cargo_esc = cargo.replace("'", "''")

    tuplas_sql.append(f"('{nome_esc}','{email_esc}','{senha_hash_java}','{telefone}','{nascimento}','{cargo_esc}','{foto_esc}')")

sql_insert = (
    "INSERT INTO admin(nome,email,senha,telefone,nascimento,cargo,foto)\nVALUES\n"
    + ",\n".join(tuplas_sql)
    + ";"
)

print(sql_insert)
# Out:
# INSERT INTO admin(nome,email,senha,telefone,nascimento,cargo,foto)
# VALUES
# ('Andreas Dezen Silva','andreas.germinare@gmail.com','$2a$12$PigezjxpRyx5n2oH/0Y5ee/.CqBOAHrKsa1qwTzr9hLANlQ3yfjC2','11978562442','2010-08-16','Analista','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_1_nsvs4o.jpg'),
# ('Beatriz Teixeira Marioti','b.tmarioti3.0@gmail.com','$2a$12$Yo9RLHoxz8CRbcJyhS6ye.weuOewD4PSsHGtVqaeFbJCOKhWFZDQG','11913139297','2008-09-09','Scrum Master','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.02_gmd38y.jpg'),
# ('Caio de Oliveira Garcia','caiodegarcia.oficial@gmail.com','$2a$12$vog0Y.Tr78ArvhhS/0MGVemm3eTr8RitiZIChAXwaTKpgrJAHNuou','11984858093','2008-05-20','Analista','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761661655/WhatsApp_Image_2025-10-28_at_10.03.59_g0coyl.jpg'),
# ...

# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela admin
#
# Esse código gera dados fictícios para inserir na tabela `admin` do banco, usando Python e a Biblioteca ByCript
#
# ---

# %% [markdown]
# Caso não esteja instalado, execute o comando abaixo:

# %%
# !pip install bcrypt --quiet

# %% [markdown]
# ## Imports

# %%
# Importações necessárias
import bcrypt

# %% [markdown]
# ## Lista de administradores
# Cada tupla contém: nome, email, telefone, data de nascimento, cargo e URL da foto hospedada no Cloudinary.

# %%
admins = [
    ("Andreas Dezen Silva","andreas.germinare@gmail.com","11978562442","2010-08-16","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_1_nsvs4o.jpg"),
    ("Beatriz Teixeira Marioti","b.tmarioti3.0@gmail.com","11913139297","2008-09-09","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.02_gmd38y.jpg"),
    ("Caio de Oliveira Garcia","caiodegarcia.oficial@gmail.com","11984858093","2008-05-20","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761661655/WhatsApp_Image_2025-10-28_at_10.03.59_g0coyl.jpg"),
    ("Enzo D´angio Mota","enzo.mota@germinare.org.br","11992866128","2010-03-te12","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_g97uhz.jpg"),
    ("Gabriel Ferreira Texeira","gabriel.ferreira@germinare.org.br","11972721701","2009-01-17","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575509/WhatsApp_Image_2025-10-27_at_11.31.31_nsvwb1.jpg"),
    ("Giovanna Almeida dos Santos","gihalmeida127@gmail.com","11942026405","2010-01-17","Scrum Master","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575151/WhatsApp_Image_2025-10-27_at_11.21.58_lhk3eg.jpg"),
    ("Giovanna Medeiros Veloso","giovanna.veloso@germinare.org.br","11997831648","2009-07-31","Desenvolvedora","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575133/WhatsApp_Image_2025-10-27_at_11.21.57_atpip0.jpg"),
    ("Giulia Galeote Santana Oliveira","giulia.gso.2008@gmail.com","11953062483","2008-08-19","Desenvolvedora","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.03_1_pz2e42.jpg"),
    ("Giulia Monteiro Manara","giulia.manara@germinare.org.br","11969803064","2009-06-09","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.00_efzdhe.jpg"),
    ("Lívia Izidório","liviaizidorio.li@gmail.com","11987307953","2008-12-22","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.03_u0h0ra.jpg"),
    ("Luis Henrique Medeiros","luis.medeiros@germinare.org.br","11939603223","2009-04-05","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.21.57_1_zmppzr.jpg"),
    ("Luke Francischini Pereira dos Santos","pereiraluke12@gmail.com","11960648215","2008-11-25","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575152/WhatsApp_Image_2025-10-27_at_11.21.58_1_aaxtkx.jpg"),
    ("Mariana Marrão Ferreira Felis","mariana.felis@germinare.org.br","11941286166","2010-01-15","Analista","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.21.59_zxvoix.jpg"),
    ("Marcos Guilherme Araújo","marcosedaviaraujo@gmail.com","11950056954","2009-01-02","Desenvolvedor","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575152/WhatsApp_Image_2025-10-27_at_11.21.58_1_aaxtkx.jpg"),
    ("Matheus Lima Botana Gama","matheus.gama@germinare.org.br","11983147995","2010-02-14","Product Owner","https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575158/WhatsApp_Image_2025-10-27_at_11.21.57_2_jeb7au.jpg")
]

# %% [markdown]
# ## Geração do Script SQL
# Cada registro recebe a senha padrão '1234567810' criptografada com bcrypt

# %%
senha_plain = "1234567810"

print("INSERT INTO admin(nome,email,senha,telefone,nascimento,cargo,foto) VALUES")

for i, (nome, email, telefone, nascimento, cargo, foto) in enumerate(admins):
    hash_bytes = bcrypt.hashpw(senha_plain.encode('utf-8'), bcrypt.gensalt(12))
    senha_hash = hash_bytes.decode('utf-8')
    senha_hash_java = senha_hash.replace("$2b$", "$2a$").replace("$2y$", "$2a$")

    nome_esc = nome.replace("'", "''")
    email_esc = email.replace("'", "''")
    foto_esc = foto.replace("'", "''")
    cargo_esc = cargo.replace("'", "''")

    if i < len(admins) - 1:
        print(f"('{nome_esc}','{email_esc}','{senha_hash_java}','{telefone}','{nascimento}','{cargo_esc}','{foto_esc}'),")
    else:
        print(f"('{nome_esc}','{email_esc}','{senha_hash_java}','{telefone}','{nascimento}','{cargo_esc}','{foto_esc}');")
# Out:
# INSERT INTO admin(nome,email,senha,telefone,nascimento,cargo,foto) VALUES
# ('Andreas Dezen Silva','andreas.germinare@gmail.com','$2a$12$UBG4gWdMCFdhWep0DxBpbORrZgEdyB/iyFbqe3OH7iLtN8scylMG.','11978562442','2010-08-16','Analista','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.01_1_nsvs4o.jpg'),
# ('Beatriz Teixeira Marioti','b.tmarioti3.0@gmail.com','$2a$12$SZ7Zv2bZopxwRfp7oZQX4.wS/UzLtBWwCzUf1ClxXcnlnDGQJGt5i','11913139297','2008-09-09','Scrum Master','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761575153/WhatsApp_Image_2025-10-27_at_11.22.02_gmd38y.jpg'),
# ('Caio de Oliveira Garcia','caiodegarcia.oficial@gmail.com','$2a$12$cKzhrPl2usk0ajxFzRm7tetvddYhpavjF4nxVNo.u6Fv.D0jOUGwO','11984858093','2008-05-20','Analista','https://res.cloudinary.com/dtvvd7xif/image/upload/v1761661655/WhatsApp_Image_2025-10-28_at_10.03.59_g0coyl.jpg'),
# ...
