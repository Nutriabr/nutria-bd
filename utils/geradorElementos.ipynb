# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela elementos
#
# Esse código gera dados fictícios para inserir na tabela `elementos` do banco, usando Python para simular registros realistas.
#
# ---

# %% [markdown]
# ## Gerando 20 registros e imprimindo no formato SQL

# %%
# Começa a imprimir o comando SQL de inserção, 
# com os nomes das colunas da tabela 'elementos'

print("INSERT INTO elementos (id_receita, id_ingredientes)\nVALUES",end="")
for i in range(20):
    id_receita = i + 1 
    id_ingredientes = i + 1

    if i < 19:
        print(f"({id_receita}, {id_ingredientes}),")
    else:
        print(f"({id_receita}, {id_ingredientes});")
