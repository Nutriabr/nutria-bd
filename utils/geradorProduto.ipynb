# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela Produto
#
# Esse código gera dados fictícios para inserir na tabela `produto` do banco, usando Python e a biblioteca Random para simular registros realistas.
#
# ---

# %% [markdown]
# ## Gerando 20 registros com informações aleatórias e imprimindo no formato SQL

# %%
nomes = [
    "Bolo de Açúcar e Canela",
    "Arroz com Feijão",
    "Purê de Batata",
    "Salada de Cebola e Queijo Mussarela",
    "Ovos Mexidos com Manteiga",
    "Pão de Mel com Chocolate Meio Amargo",
    "Panqueca de Farinha de Trigo e Leite Integral",
    "Cookie de Aveia e Mel",
    "Frango ao Vinagre com Pimenta-do-Reino",
    "Molho de Tomate com Sal e Alho",
    "Risoto de Arroz com Queijo Mussarela",
    "Feijoada Tradicional",
    "Biscoito de Amido de Milho",
    "Torta de Batata com Queijo Mussarela",
    "Bolo de Chocolate Meio Amargo",
    "Omelete de Ovo com Queijo Mussarela",
    "Pão de Queijo",
    "Batata Assada",
    "Caldo Verde",
    "Panetone com Açúcar e Canela"
]

# Começa a imprimir o comando SQL de inserção, 
# com os nomes das colunas da tabela 'ingredientes'

print("INSERT INTO produto (nome,id_usuario)\nVALUES ",end="")

for i in range(len(nomes)):
    nome = nomes[i]
    # Imprime os valores formatados para inserir no banco
    if (i < 19):
        print(f"('{nome}',{i+1}),")
    else:
        print(f"('{nome}',{i+1});")
# Out:
# INSERT INTO produto (nome,id_usuario)
# VALUES ('Bolo de Açúcar e Canela',1),
# ('Arroz com Feijão',2),
# ('Purê de Batata',3),
# ('Salada de Cebola e Queijo Mussarela',4),
# ('Ovos Mexidos com Manteiga',5),
# ('Pão de Mel com Chocolate Meio Amargo',6),
# ('Panqueca de Farinha de Trigo e Leite Integral',7),
# ('Cookie de Aveia e Mel',8),
# ('Frango ao Vinagre com Pimenta-do-Reino',9),
# ('Molho de Tomate com Sal e Alho',10),
# ('Risoto de Arroz com Queijo Mussarela',11),
# ('Feijoada Tradicional',12),
# ('Biscoito de Amido de Milho',13),
# ('Torta de Batata com Queijo Mussarela',14),
# ('Bolo de Chocolate Meio Amargo',15),
# ('Omelete de Ovo com Queijo Mussarela',16),
# ('Pão de Queijo',17),
# ('Batata Assada',18),
# ('Caldo Verde',19),
# ('Panetone com Açúcar e Canela',20);
