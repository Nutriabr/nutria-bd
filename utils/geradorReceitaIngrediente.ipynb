# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela elementos
#
# Esse código gera dados fictícios para inserir na tabela `Receita_Ingrediente` do banco, usando Python para simular registros realistas.
#
# ---

# %% [markdown]
# ## Imports

# %%
# Importações necessárias
import random as rd

# %% [markdown]
# ## Gerando 20 registros e imprimindo no formato SQL

# %%
# Começa a imprimir o comando SQL de inserção, 
# com os nomes das colunas da tabela 'elementos'

print("INSERT INTO receita_ingrediente (id_receita, id_ingrediente,quantidade)\nVALUES",end="")
for i in range(20):
    id_receita = i + 1 
    id_ingrediente = i + 1
    quantidade = rd.randint(1,1000)

    if i < 19:
        print(f"({id_receita}, {id_ingrediente}, {quantidade}),")
    else:
        print(f"({id_receita}, {id_ingrediente}, {quantidade});")
# Out:
# INSERT INTO receita_ingrediente (id_receita, id_ingrediente,quantidade)
# VALUES(1, 1, 900),
# (2, 2, 605),
# (3, 3, 583),
# (4, 4, 371),
# (5, 5, 803),
# (6, 6, 650),
# (7, 7, 517),
# (8, 8, 35),
# (9, 9, 25),
# (10, 10, 715),
# (11, 11, 359),
# (12, 12, 134),
# (13, 13, 218),
# (14, 14, 299),
# (15, 15, 765),
# (16, 16, 390),
# (17, 17, 27),
# (18, 18, 231),
# (19, 19, 74),
# (20, 20, 704);
