# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela elementos
#
# Esse código gera dados fictícios para inserir na tabela `Receita_Ingredientes` do banco, usando Python para simular registros realistas.
#
# ---

# %% [markdown]
# ## Imports

# %%
# Importações necessárias
import random as rd

# %% [markdown]
# ## Gerando 20 registros e imprimindo no formato SQL

# %%
# Começa a imprimir o comando SQL de inserção, 
# com os nomes das colunas da tabela 'elementos'

print("INSERT INTO receita_ingrediente (id_receita, id_ingrediente,quantidade)\nVALUES",end="")
for i in range(20):
    id_receita = i + 1 
    id_ingrediente = i + 1
    quantidade = rd.randint(1,1000)

    if i < 19:
        print(f"({id_receita}, {id_ingrediente}, {quantidade}),")
    else:
        print(f"({id_receita}, {id_ingrediente}, {quantidade});")
# Out:
# INSERT INTO receita_ingrediente (id_receita, id_ingredientes,quantidade)
# VALUES(1, 1, 905),
# (2, 2, 509),
# (3, 3, 451),
# (4, 4, 695),
# (5, 5, 500),
# (6, 6, 379),
# (7, 7, 161),
# (8, 8, 341),
# (9, 9, 175),
# (10, 10, 550),
# (11, 11, 709),
# (12, 12, 387),
# (13, 13, 555),
# (14, 14, 434),
# (15, 15, 763),
# (16, 16, 126),
# (17, 17, 479),
# (18, 18, 129),
# (19, 19, 383),
# (20, 20, 241);
