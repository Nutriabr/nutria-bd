# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela ingredientes
#
# Esse código gera dados fictícios para inserir na tabela `ingredientes` do banco e usando Python.
#
# ---

# %% [markdown]
# ## Gerando 20 registros com dados falsos e imprimindo no formato SQL

# %%
# Dicionário com ingredientes e possíveis unidades de medida
nomes = [
    "açúcar",
    "sal",
    "farinha de trigo",
    "óleo de soja",
    "leite integral",
    "manteiga",
    "ovo",
    "amido de milho",
    "canela",
    "chocolate meio amargo",
    "aveia",
    "mel",
    "vinagre",
    "pimenta-do-reino",
    "alho",
    "feijão",
    "batata",
    "queijo mussarela", 
    "fermento químico",
    "arroz branco"
]


# Começa a imprimir o comando SQL de inserção com os nomes 

print("INSERT INTO ingrediente (nome)\nVALUES ",end="")

for i in range (len(nomes)):
    nome = nomes[i]

    # Imprime os valores formatados para inserir no banco
    if (i < len(nomes)-1):
        print(f"('{nome}'),")
    else:
        print(f"('{nome}');")
# Out:
# INSERT INTO ingrediente (nome)
# VALUES ('açúcar'),
# ('sal'),
# ('farinha de trigo'),
# ('óleo de soja'),
# ('leite integral'),
# ('manteiga'),
# ('ovo'),
# ('amido de milho'),
# ('canela'),
# ('chocolate meio amargo'),
# ('aveia'),
# ('mel'),
# ('vinagre'),
# ('pimenta-do-reino'),
# ('alho'),
# ('feijão'),
# ('batata'),
# ('queijo mussarela'),
# ('fermento químico'),
# ('arroz branco');
