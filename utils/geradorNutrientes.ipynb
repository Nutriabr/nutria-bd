# %% [markdown]
# # Notebook para o gerador de script DataLoad da tabela usuário
#
# Esse código gera dados fictícios para inserir na tabela `nutrientes` do banco, usando Python e a biblioteca Random para simular registros realistas.
#
# ---

# %% [markdown]
# ## Imports

# %%
# Importações necessárias
import random as rd

# %% [markdown]
# ## Gerando registros aleatórios e imprimindo no formato SQL

# %%
print("INSERT INTO nutrientes (carboidratos, acucares_totais, acucares_adicionados, proteinas, gorduras_totais, gorduras_saturadas, gorduras_trans, fibra_alimentar, sodio, colesterol, vitamina_A, vitamina_C, vitamina_D, calcio, ferro, potassio, magnesio, zinco, fosforo) \nVALUES",end="")

for i in range(20):
    carboidratos = f"{rd.randint(0, 100)}g"
    acucares_totais = f"{rd.randint(0, 80)}g"
    acucares_adicionados = f"{rd.randint(0, 60)}g"
    proteinas = f"{rd.randint(0, 60)}g"
    gorduras_totais = f"{rd.randint(0, 50)}g"
    gorduras_saturadas = f"{rd.randint(0, 20)}g"
    gorduras_trans = f"{rd.randint(0, 2)}g"
    fibra_alimentar = f"{rd.randint(0, 15)}g"
    sodio = f"{rd.randint(0, 1200)}mg"
    colesterol = f"{rd.randint(0, 200)}mg"
    vitamina_A = f"{rd.randint(0, 900)}µg RE"
    vitamina_C = f"{rd.randint(0, 100)}mg"
    vitamina_D = f"{rd.randint(0, 35)}µg"
    calcio = f"{rd.randint(0, 500)}mg"
    ferro = f"{rd.randint(0, 20)}mg"
    potassio = f"{rd.randint(0, 1000)}mg"
    magnesio = f"{rd.randint(0, 200)}mg"
    zinco = f"{rd.randint(0, 10)}mg"
    fosforo = f"{rd.randint(0, 400)}mg"

    if (i < 19):
            print(f"('{carboidratos}', '{acucares_totais}', '{acucares_adicionados}', '{proteinas}', '{gorduras_totais}', '{gorduras_saturadas}', '{gorduras_trans}', '{fibra_alimentar}', '{sodio}', '{colesterol}', '{vitamina_A}', '{vitamina_C}', '{vitamina_D}', '{calcio}', '{ferro}', '{potassio}', '{magnesio}', '{zinco}', '{fosforo}') ,")
    else:
            print(f"('{carboidratos}', '{acucares_totais}', '{acucares_adicionados}', '{proteinas}', '{gorduras_totais}', '{gorduras_saturadas}', '{gorduras_trans}', '{fibra_alimentar}', '{sodio}', '{colesterol}', '{vitamina_A}', '{vitamina_C}', '{vitamina_D}', '{calcio}', '{ferro}', '{potassio}', '{magnesio}', '{zinco}', '{fosforo}') ;")
